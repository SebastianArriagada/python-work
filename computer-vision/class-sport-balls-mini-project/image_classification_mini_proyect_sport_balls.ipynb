# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianArriagada/computer-vision/blob/main/mini_proyect_sport_balls/image_classification_mini_proyect_sport_balls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download database from Kaggle \
# It requires the file "kaggle.json", obtained from kaggle.com -> account -> Create New API Token

# %%
# !pip install -q kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d gpiosenka/balls-image-classification
# !mkdir ~/.data
# !unzip balls-image-classification.zip -d data

# %% [markdown]
# Looking inside the folders to see how many examples there are of each label

# %%
from pathlib import Path
from os import listdir
from tabulate import tabulate
import numpy as np 
# prefix components:
space =  '    '
branch = '│   '
# pointers:
tee =    '├── '
last =   '└── '

def tree(dir_path: Path, prefix: str='', onlyNumberOfFiles = False):
    """A recursive generator, given a directory Path object
    will yield a visual tree structure line by line
    with each line prefixed by the same characters
    """    
    if onlyNumberOfFiles:
      yield f'{prefix}{last} {len(listdir(dir_path))}'
    else:
      contents = list(dir_path.iterdir())
      pointers = [tee] * (len(contents) - 1) + [last]
      for pointer, path in zip(pointers, contents):
          yield prefix + pointer + path.name
          if path.is_dir(): # extend the prefix and recurse:
              extension = branch if pointer == tee else space 
              # i.e. space because last, └── , above so no more |
              yield from tree(path, prefix=prefix+extension, onlyNumberOfFiles = True)

trainTree = tree(Path.home() / '/content/data/train')
testTree = tree(Path.home() / '/content/data/test')
validTree = tree(Path.home() / '/content/data/valid')
train, test, valid = [], [], []
for lineTrain, lineTest, lineValid in zip(trainTree, testTree, validTree):
    train.append(lineTrain)
    test.append(lineTest)
    valid.append(lineValid)
    #print(lineTrain, lineTest)

print(tabulate(zip(train ,test, valid), headers=['Train', 'Test', 'Valid']))
# Out:
# Train                Test                 Valid
# -------------------  -------------------  -------------------
# ├── bowling ball     ├── bowling ball     ├── bowling ball
# │   └──  145         │   └──  5           │   └──  5
# ├── golf ball        ├── golf ball        ├── golf ball
# │   └──  106         │   └──  5           │   └──  5
# ├── beachballs       ├── beachballs       ├── beachballs
# │   └──  92          │   └──  5           │   └──  5
# ├── medicine ball    ├── medicine ball    ├── medicine ball
# │   └──  77          │   └──  5           │   └──  5
# ├── eyeballs         ├── eyeballs         ├── eyeballs
# │   └──  139         │   └──  5           │   └──  5
# ├── paint balls      ├── paint balls      ├── paint balls
# │   └──  32          │   └──  5           │   └──  5
# ├── wrecking ball    ├── wrecking ball    ├── wrecking ball
# │   └──  69          │   └──  5           │   └──  5
# ├── meat ball        ├── meat ball        ├── meat ball
# │   └──  137         │   └──  5           │   └──  5
# ├── soccer ball      ├── soccer ball      ├── soccer ball
# │   └──  167         │   └──  5           │   └──  5
# ├── tennis ball      ├── tennis ball      ├── tennis ball
# │   └──  139         │   └──  5           │   └──  5
# ├── basketball       ├── basketball       ├── basketball
# │   └──  116         │   └──  5           │   └──  5
# ├── brass            ├── brass            ├── brass
# │   └──  113         │   └──  5           │   └──  5
# ├── water polo ball  ├── water polo ball  ├── water polo ball
# │   └──  139         │   └──  5           │   └──  5
# ├── volley ball      ├── volley ball      ├── volley ball
# │   └──  131         │   └──  5           │   └──  5
# ├── cricket ball     ├── cricket ball     ├── cricket ball
# │   └──  150         │   └──  5           │   └──  5
# ├── wiffle ball      ├── wiffle ball      ├── wiffle ball
# │   └──  99          │   └──  5           │   └──  5
# ├── puffballs        ├── puffballs        ├── puffballs
# │   └──  106         │   └──  5           │   └──  5
# ├── baseball         ├── baseball         ├── baseball
# │   └──  112         │   └──  5           │   └──  5
# ├── pokeman balls    ├── pokeman balls    ├── pokeman balls
# │   └──  86          │   └──  5           │   └──  5
# ├── tether ball      ├── tether ball      ├── tether ball
# │   └──  105         │   └──  5           │   └──  5
# ├── screwballs       ├── screwballs       ├── screwballs
# │   └──  140         │   └──  5           │   └──  5
# ├── buckeyballs      ├── buckeyballs      ├── buckeyballs
# │   └──  82          │   └──  5           │   └──  5
# ├── marble           ├── marble           ├── marble
# │   └──  131         │   └──  5           │   └──  5
# ├── billiard ball    ├── billiard ball    ├── billiard ball
# │   └──  143         │   └──  5           │   └──  5
# ├── football         ├── football         ├── football
# │   └──  112         │   └──  5           │   └──  5
# └── cannon ball      └── cannon ball      └── cannon ball
# └──  183             └──  5               └──  5

# %% [markdown]
# Building the database from the folders, taking the name of each folder as a label

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory
import pandas as pd
import os
import numpy as np
import tensorflow as tf

# Training step 

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '/content/data/train',
    labels='inferred',
    label_mode='categorical' ,
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '/content/data/valid',
    labels='inferred',
    label_mode= 'categorical' ,
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE

ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 3051 files belonging to 26 classes.
# Found 130 files belonging to 26 classes.

# %% [markdown]
# Create model in Keras using the structure of VGG16

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

# Defiing a model using Keras 
model3 = keras.Sequential([
    # give the input dimensions in the first layer
    # [height, width, color channels(RGB)]
    layers.InputLayer(input_shape=[128, 128, 3]),
                          
    # Data Augmentation
    # layers.RandomFlip("horizontal_and_vertical"),
    # layers.RandomRotation(0.5),
    #layers.RandomContrast(0.2),
    # layers.RandomZoom(0.5),

    # First Convolutional Block
    layers.Conv2D(filters=64, kernel_size=(3,3), activation="relu", padding='same',input_shape=[128, 128, 3]),
    layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding='same'),
    layers.MaxPool2D(pool_size = (2,2), strides=(2,2)),

    # Second Convolutional Block
    layers.Conv2D(filters=128, kernel_size=(3,3),activation="relu", padding='same'),
    layers.Conv2D(filters=128, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(pool_size = (2,2), strides=(2,2)),

    # Third Convolutional Block
    layers.Conv2D(filters=256, kernel_size=(3,3), activation="relu", padding='same'),
    layers.Conv2D(filters=256, kernel_size=(3,3), activation="relu", padding='same'),
    layers.Conv2D(filters=256, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(pool_size = (2,2), strides=(2,2)),

    # Fourth Convolutional Block
    layers.Conv2D(filters=512, kernel_size=(3,3), activation="relu", padding='same'),
    layers.Conv2D(filters=512, kernel_size=(3,3),activation="relu", padding='same'),
    layers.Conv2D(filters=512, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(pool_size = (2,2), strides=(2,2)),

    # Fifth Convolutional Block
    layers.Conv2D(filters=512, kernel_size=(3,3), activation="relu", padding='same'),
    layers.Conv2D(filters=512, kernel_size=(3,3),activation="relu", padding='same'),
    layers.Conv2D(filters=512, kernel_size=(3,3), activation="relu", padding='same'),
    layers.MaxPool2D(pool_size = (2,2), strides=(2,2)),

    # Classifier Head
    layers.Flatten(),
    layers.Dense(units=4096, activation="relu"),
    layers.Dropout(0.8),
    layers.Dense(units=4096, activation="relu"),
    layers.Dropout(0.2),
    layers.Dense(units=26, activation="softmax"),
])
model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip_1 (RandomFlip)  (None, 128, 128, 3)       0
#
#  random_rotation_1 (RandomRo  (None, 128, 128, 3)      0
#  tation)
#
#  random_zoom_1 (RandomZoom)  (None, 128, 128, 3)       0
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 64)      1792
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 64)      36928
#
#  max_pooling2d_5 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 128)       73856
#
#  conv2d_16 (Conv2D)          (None, 64, 64, 128)       147584
#
#  max_pooling2d_6 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 256)       295168
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 256)       590080
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 256)       590080
#
#  max_pooling2d_7 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 16, 16, 512)       1180160
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  max_pooling2d_8 (MaxPooling  (None, 8, 8, 512)        0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  conv2d_24 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  conv2d_25 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  max_pooling2d_9 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_3 (Dense)             (None, 4096)              33558528
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 26)                106522
#
# =================================================================
# Total params: 65,161,050
# Trainable params: 65,161,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# Setting save options
checkpoint = ModelCheckpoint("vgg16_no_aum.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')

# Setting training options
model3.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Training the model 
history = model3.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
    callbacks=[checkpoint],
)

# Display the training history 
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot()

test_loss, test_acc = model.evaluate(ds_valid, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# Epoch 1/50
# 48/48 [==============================] - ETA: 0s - loss: 3.2518 - accuracy: 0.0492
# Epoch 00001: val_accuracy improved from -inf to 0.03846, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 33s 658ms/step - loss: 3.2518 - accuracy: 0.0492 - val_loss: 3.2615 - val_accuracy: 0.0385
# Epoch 2/50
# 48/48 [==============================] - ETA: 0s - loss: 3.2309 - accuracy: 0.0567
# Epoch 00002: val_accuracy did not improve from 0.03846
# 48/48 [==============================] - 29s 602ms/step - loss: 3.2309 - accuracy: 0.0567 - val_loss: 3.2890 - val_accuracy: 0.0385
# Epoch 3/50
# 48/48 [==============================] - ETA: 0s - loss: 3.2259 - accuracy: 0.0547
# Epoch 00003: val_accuracy did not improve from 0.03846
# 48/48 [==============================] - 29s 601ms/step - loss: 3.2259 - accuracy: 0.0547 - val_loss: 3.3004 - val_accuracy: 0.0385
# Epoch 4/50
# 48/48 [==============================] - ETA: 0s - loss: 3.2254 - accuracy: 0.0570
# Epoch 00004: val_accuracy did not improve from 0.03846
# 48/48 [==============================] - 29s 601ms/step - loss: 3.2254 - accuracy: 0.0570 - val_loss: 3.2970 - val_accuracy: 0.0385
# Epoch 5/50
# 48/48 [==============================] - ETA: 0s - loss: 3.2215 - accuracy: 0.0610
# Epoch 00005: val_accuracy did not improve from 0.03846
# 48/48 [==============================] - 29s 601ms/step - loss: 3.2215 - accuracy: 0.0610 - val_loss: 3.2926 - val_accuracy: 0.0385
# Epoch 6/50
# 48/48 [==============================] - ETA: 0s - loss: 3.2196 - accuracy: 0.0580
# Epoch 00006: val_accuracy did not improve from 0.03846
# 48/48 [==============================] - 29s 600ms/step - loss: 3.2196 - accuracy: 0.0580 - val_loss: 3.2911 - val_accuracy: 0.0385
# Epoch 7/50
# 48/48 [==============================] - ETA: 0s - loss: 3.2080 - accuracy: 0.0665
# Epoch 00007: val_accuracy improved from 0.03846 to 0.06923, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 651ms/step - loss: 3.2080 - accuracy: 0.0665 - val_loss: 3.2220 - val_accuracy: 0.0692
# Epoch 8/50
# 48/48 [==============================] - ETA: 0s - loss: 3.1066 - accuracy: 0.0924
# Epoch 00008: val_accuracy did not improve from 0.06923
# 48/48 [==============================] - 29s 597ms/step - loss: 3.1066 - accuracy: 0.0924 - val_loss: 3.1377 - val_accuracy: 0.0692
# Epoch 9/50
# 48/48 [==============================] - ETA: 0s - loss: 2.9207 - accuracy: 0.1314
# Epoch 00009: val_accuracy improved from 0.06923 to 0.10000, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 655ms/step - loss: 2.9207 - accuracy: 0.1314 - val_loss: 2.8678 - val_accuracy: 0.1000
# Epoch 10/50
# 48/48 [==============================] - ETA: 0s - loss: 2.8028 - accuracy: 0.1639
# Epoch 00010: val_accuracy improved from 0.10000 to 0.12308, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 653ms/step - loss: 2.8028 - accuracy: 0.1639 - val_loss: 2.9076 - val_accuracy: 0.1231
# Epoch 11/50
# 48/48 [==============================] - ETA: 0s - loss: 2.7403 - accuracy: 0.1796
# Epoch 00011: val_accuracy improved from 0.12308 to 0.17692, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 651ms/step - loss: 2.7403 - accuracy: 0.1796 - val_loss: 2.6401 - val_accuracy: 0.1769
# Epoch 12/50
# 48/48 [==============================] - ETA: 0s - loss: 2.6182 - accuracy: 0.2189
# Epoch 00012: val_accuracy improved from 0.17692 to 0.20000, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 652ms/step - loss: 2.6182 - accuracy: 0.2189 - val_loss: 2.6349 - val_accuracy: 0.2000
# Epoch 13/50
# 48/48 [==============================] - ETA: 0s - loss: 2.5286 - accuracy: 0.2373
# Epoch 00013: val_accuracy improved from 0.20000 to 0.24615, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 654ms/step - loss: 2.5286 - accuracy: 0.2373 - val_loss: 2.4534 - val_accuracy: 0.2462
# Epoch 14/50
# 48/48 [==============================] - ETA: 0s - loss: 2.4572 - accuracy: 0.2645
# Epoch 00014: val_accuracy did not improve from 0.24615
# 48/48 [==============================] - 28s 591ms/step - loss: 2.4572 - accuracy: 0.2645 - val_loss: 2.4301 - val_accuracy: 0.2462
# Epoch 15/50
# 48/48 [==============================] - ETA: 0s - loss: 2.3934 - accuracy: 0.2819
# Epoch 00015: val_accuracy improved from 0.24615 to 0.25385, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 650ms/step - loss: 2.3934 - accuracy: 0.2819 - val_loss: 2.4000 - val_accuracy: 0.2538
# Epoch 16/50
# 48/48 [==============================] - ETA: 0s - loss: 2.2709 - accuracy: 0.3186
# Epoch 00016: val_accuracy improved from 0.25385 to 0.30769, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 649ms/step - loss: 2.2709 - accuracy: 0.3186 - val_loss: 2.1921 - val_accuracy: 0.3077
# Epoch 17/50
# 48/48 [==============================] - ETA: 0s - loss: 2.2472 - accuracy: 0.3337
# Epoch 00017: val_accuracy improved from 0.30769 to 0.32308, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 649ms/step - loss: 2.2472 - accuracy: 0.3337 - val_loss: 2.1942 - val_accuracy: 0.3231
# Epoch 18/50
# 48/48 [==============================] - ETA: 0s - loss: 2.1261 - accuracy: 0.3632
# Epoch 00018: val_accuracy improved from 0.32308 to 0.33846, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 32s 658ms/step - loss: 2.1261 - accuracy: 0.3632 - val_loss: 2.1176 - val_accuracy: 0.3385
# Epoch 19/50
# 48/48 [==============================] - ETA: 0s - loss: 1.9942 - accuracy: 0.4123
# Epoch 00019: val_accuracy improved from 0.33846 to 0.35385, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 648ms/step - loss: 1.9942 - accuracy: 0.4123 - val_loss: 2.0963 - val_accuracy: 0.3538
# Epoch 20/50
# 48/48 [==============================] - ETA: 0s - loss: 1.8818 - accuracy: 0.4418
# Epoch 00020: val_accuracy improved from 0.35385 to 0.42308, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 648ms/step - loss: 1.8818 - accuracy: 0.4418 - val_loss: 1.8563 - val_accuracy: 0.4231
# Epoch 21/50
# 48/48 [==============================] - ETA: 0s - loss: 1.8571 - accuracy: 0.4523
# Epoch 00021: val_accuracy improved from 0.42308 to 0.43846, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 647ms/step - loss: 1.8571 - accuracy: 0.4523 - val_loss: 1.8375 - val_accuracy: 0.4385
# Epoch 22/50
# 48/48 [==============================] - ETA: 0s - loss: 1.7048 - accuracy: 0.5002
# Epoch 00022: val_accuracy did not improve from 0.43846
# 48/48 [==============================] - 28s 589ms/step - loss: 1.7048 - accuracy: 0.5002 - val_loss: 1.8882 - val_accuracy: 0.4154
# Epoch 23/50
# 48/48 [==============================] - ETA: 0s - loss: 1.6925 - accuracy: 0.4985
# Epoch 00023: val_accuracy did not improve from 0.43846
# 48/48 [==============================] - 28s 589ms/step - loss: 1.6925 - accuracy: 0.4985 - val_loss: 1.9122 - val_accuracy: 0.4154
# Epoch 24/50
# 48/48 [==============================] - ETA: 0s - loss: 1.5761 - accuracy: 0.5284
# Epoch 00024: val_accuracy improved from 0.43846 to 0.48462, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 647ms/step - loss: 1.5761 - accuracy: 0.5284 - val_loss: 1.8085 - val_accuracy: 0.4846
# Epoch 25/50
# 48/48 [==============================] - ETA: 0s - loss: 1.4614 - accuracy: 0.5516
# Epoch 00025: val_accuracy did not improve from 0.48462
# 48/48 [==============================] - 28s 590ms/step - loss: 1.4614 - accuracy: 0.5516 - val_loss: 1.7887 - val_accuracy: 0.4846
# Epoch 26/50
# 48/48 [==============================] - ETA: 0s - loss: 1.4564 - accuracy: 0.5598
# Epoch 00026: val_accuracy did not improve from 0.48462
# 48/48 [==============================] - 28s 588ms/step - loss: 1.4564 - accuracy: 0.5598 - val_loss: 2.0797 - val_accuracy: 0.4231
# Epoch 27/50
# 48/48 [==============================] - ETA: 0s - loss: 1.3227 - accuracy: 0.6014
# Epoch 00027: val_accuracy did not improve from 0.48462
# 48/48 [==============================] - 28s 590ms/step - loss: 1.3227 - accuracy: 0.6014 - val_loss: 1.7697 - val_accuracy: 0.4769
# Epoch 28/50
# 48/48 [==============================] - ETA: 0s - loss: 1.2519 - accuracy: 0.6165
# Epoch 00028: val_accuracy improved from 0.48462 to 0.56923, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 647ms/step - loss: 1.2519 - accuracy: 0.6165 - val_loss: 1.5601 - val_accuracy: 0.5692
# Epoch 29/50
# 48/48 [==============================] - ETA: 0s - loss: 1.1189 - accuracy: 0.6532
# Epoch 00029: val_accuracy did not improve from 0.56923
# 48/48 [==============================] - 28s 589ms/step - loss: 1.1189 - accuracy: 0.6532 - val_loss: 1.6816 - val_accuracy: 0.5000
# Epoch 30/50
# 48/48 [==============================] - ETA: 0s - loss: 1.0760 - accuracy: 0.6657
# Epoch 00030: val_accuracy did not improve from 0.56923
# 48/48 [==============================] - 28s 588ms/step - loss: 1.0760 - accuracy: 0.6657 - val_loss: 1.7865 - val_accuracy: 0.4846
# Epoch 31/50
# 48/48 [==============================] - ETA: 0s - loss: 1.0138 - accuracy: 0.6899
# Epoch 00031: val_accuracy did not improve from 0.56923
# 48/48 [==============================] - 28s 588ms/step - loss: 1.0138 - accuracy: 0.6899 - val_loss: 2.5008 - val_accuracy: 0.3923
# Epoch 32/50
# 48/48 [==============================] - ETA: 0s - loss: 1.0140 - accuracy: 0.7011
# Epoch 00032: val_accuracy did not improve from 0.56923
# 48/48 [==============================] - 28s 587ms/step - loss: 1.0140 - accuracy: 0.7011 - val_loss: 2.6641 - val_accuracy: 0.4154
# Epoch 33/50
# 48/48 [==============================] - ETA: 0s - loss: 1.0839 - accuracy: 0.6739
# Epoch 00033: val_accuracy improved from 0.56923 to 0.57692, saving model to vgg16_no_aum.h5
# 48/48 [==============================] - 31s 643ms/step - loss: 1.0839 - accuracy: 0.6739 - val_loss: 1.6646 - val_accuracy: 0.5769
# Epoch 34/50
# 48/48 [==============================] - ETA: 0s - loss: 0.9263 - accuracy: 0.7175
# Epoch 00034: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 586ms/step - loss: 0.9263 - accuracy: 0.7175 - val_loss: 1.7394 - val_accuracy: 0.5538
# Epoch 35/50
# 48/48 [==============================] - ETA: 0s - loss: 0.8125 - accuracy: 0.7486
# Epoch 00035: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 584ms/step - loss: 0.8125 - accuracy: 0.7486 - val_loss: 1.6750 - val_accuracy: 0.5385
# Epoch 36/50
# 48/48 [==============================] - ETA: 0s - loss: 0.6072 - accuracy: 0.8099
# Epoch 00036: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 588ms/step - loss: 0.6072 - accuracy: 0.8099 - val_loss: 1.8429 - val_accuracy: 0.5769
# Epoch 37/50
# 48/48 [==============================] - ETA: 0s - loss: 0.5287 - accuracy: 0.8361
# Epoch 00037: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 587ms/step - loss: 0.5287 - accuracy: 0.8361 - val_loss: 2.0493 - val_accuracy: 0.5462
# Epoch 38/50
# 48/48 [==============================] - ETA: 0s - loss: 0.4992 - accuracy: 0.8492
# Epoch 00038: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 587ms/step - loss: 0.4992 - accuracy: 0.8492 - val_loss: 1.9139 - val_accuracy: 0.5692
# Epoch 39/50
# 48/48 [==============================] - ETA: 0s - loss: 0.4775 - accuracy: 0.8535
# Epoch 00039: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 586ms/step - loss: 0.4775 - accuracy: 0.8535 - val_loss: 2.0509 - val_accuracy: 0.5385
# Epoch 40/50
# 48/48 [==============================] - ETA: 0s - loss: 0.4159 - accuracy: 0.8666
# Epoch 00040: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 585ms/step - loss: 0.4159 - accuracy: 0.8666 - val_loss: 2.1019 - val_accuracy: 0.5538
# Epoch 41/50
# 48/48 [==============================] - ETA: 0s - loss: 0.3847 - accuracy: 0.8827
# Epoch 00041: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 586ms/step - loss: 0.3847 - accuracy: 0.8827 - val_loss: 2.2756 - val_accuracy: 0.4846
# Epoch 42/50
# 48/48 [==============================] - ETA: 0s - loss: 0.3339 - accuracy: 0.8987
# Epoch 00042: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 585ms/step - loss: 0.3339 - accuracy: 0.8987 - val_loss: 2.3592 - val_accuracy: 0.5000
# Epoch 43/50
# 48/48 [==============================] - ETA: 0s - loss: 0.3688 - accuracy: 0.8853
# Epoch 00043: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 585ms/step - loss: 0.3688 - accuracy: 0.8853 - val_loss: 2.4448 - val_accuracy: 0.5000
# Epoch 44/50
# 48/48 [==============================] - ETA: 0s - loss: 0.3246 - accuracy: 0.8981
# Epoch 00044: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 586ms/step - loss: 0.3246 - accuracy: 0.8981 - val_loss: 2.6650 - val_accuracy: 0.5077
# Epoch 45/50
# 48/48 [==============================] - ETA: 0s - loss: 0.3481 - accuracy: 0.8935
# Epoch 00045: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 583ms/step - loss: 0.3481 - accuracy: 0.8935 - val_loss: 2.7206 - val_accuracy: 0.5308
# Epoch 46/50
# 48/48 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.9177
# Epoch 00046: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 587ms/step - loss: 0.2593 - accuracy: 0.9177 - val_loss: 2.4447 - val_accuracy: 0.5462
# Epoch 47/50
# 48/48 [==============================] - ETA: 0s - loss: 0.3182 - accuracy: 0.9056
# Epoch 00047: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 587ms/step - loss: 0.3182 - accuracy: 0.9056 - val_loss: 2.4190 - val_accuracy: 0.5385
# Epoch 48/50
# 48/48 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.9243
# Epoch 00048: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 584ms/step - loss: 0.2464 - accuracy: 0.9243 - val_loss: 2.6777 - val_accuracy: 0.5692
# Epoch 49/50
# 48/48 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9354
# Epoch 00049: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 585ms/step - loss: 0.2086 - accuracy: 0.9354 - val_loss: 3.0677 - val_accuracy: 0.5154
# Epoch 50/50
# 48/48 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9272
# Epoch 00050: val_accuracy did not improve from 0.57692
# 48/48 [==============================] - 28s 585ms/step - loss: 0.2304 - accuracy: 0.9272 - val_loss: 2.6528 - val_accuracy: 0.5077
# 3/3 - 0s - loss: 1.7979 - accuracy: 0.4462 - 490ms/epoch - 163ms/step
#
# Test accuracy: 0.446153849363327

# %%
# Loads the weights
model.load_weights('/content/vgg16.h5')

# Re-evaluate the model
ds_test_ = image_dataset_from_directory(
    '/content/data/test',
    labels='inferred',
    label_mode= 'categorical' ,
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)
ds_test = (
    ds_test_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)

loss, acc = model.evaluate(ds_test, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# Found 130 files belonging to 26 classes.
# 3/3 - 1s - loss: 1.6596 - accuracy: 0.4615 - 623ms/epoch - 208ms/step
# Restored model, accuracy: 46.15%

# %%
# Viewing results
import matplotlib.pyplot as plt

image_batch = ds_test_.take(1)
predictions = model.predict(image_batch)
plt.figure(figsize=(15, 15))
class_names = ds_test_.class_names
for images, labels in image_batch:
  predictions = model.predict(images)
  for i in range(36):
    ax = plt.subplot(6, 6, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    label = list(np.array(tf.cast(labels[i], tf.int32)))
    index = label.index(1)
    predicted_label = np.argmax(predictions[i])
    color = "green" if class_names[index ] == class_names[predicted_label] else "red"
    plt.title(" P: " + class_names[predicted_label], c = color)
    plt.axis("off")
